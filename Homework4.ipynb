# %%
# 1.Create an if statement: if 'age' is greater than or equal to 25, print "Renting a car is more affordable", however if 'age' is less than 25, print "Renting a car is very expensive."

age = int(input("Enter your age: ")) 
if age >= 25:
    print("Renting a car is more affordable.")
else:
    print("Renting a car is very expensive.")

# 2.Create and chain an if-else statement:
#  if 'age' is greater than or equal to 25, print "Renting a car is more affordable." 
# If 'age' is less than 25 but greater than or equal to 18, print "Renting a car is very expensive." 
# Finally, if age is less than 18, print "You cannot legally rent a car."

age = int(input("Enter your age: "))

if age >= 25:
    print("Renting a car is more affordable." )
if age >= 18:
    print("Renting a car is very expensive." )
else:
    print("You cannot legally rent a car.")

# 3.Loop over the following string to 
# (1) count all the characters in the string and 
# (2) print out all the vowels -- "The quick brown fox jumps over the lazy dog"

my_string = "he quick brown fox jumps over the lazy dog"
char_count = len(my_string)
print(char_count)
for vowels in my_string:
    if vowels in 'aeiou':
        print(vowels, end = " ")
       

# 4.Write a nested loop that prints out every piece of clothing from the couture list, in every fashionable color from the panettone set: 

couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"] 
panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

for x in couture:
    for y in panettone:
        print(x,y)


# 5.Use range as a loop to calculate the sum of all the numbers from 1 to 100

total_sum = 0  
for num in range(1, 101):
    total_sum += num  

print(f"The sum of all numbers from 1 to 100 is: {total_sum}")

# 6.Print the second item in this fruits list. ["apple", "banana", "cherry"]


fruits = ["apple", "banana", "cherry"]

print(fruits[1])


# 7.Change the value from "apple" to "kiwi", in the fruits list. ["apple", "banana", "cherry"]

fruits[0] = 'apple'
print(fruits)

# 8.Use the append method to add "orange" to the fruits list. ["apple", "banana", "cherry"]

fruits.append("orange")
print(fruits)

# 9.Use the insert method to add "lemon" as the second item in the fruits list. ["apple", "banana", "cherry"]

fruits.insert(1,"lemon")
print(fruits)

# 10.Use the remove method to remove "banana" from the fruits list. ["apple", "banana", "cherry"]

fruits.remove("banana")
print(fruits)

# 11.Use negative indexing to print the 3rd and 2nd to last items in the list. 

list_fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

print(list_fruits[3], list_fruits[-2])


#12.Use a range of indexes to print the third, fourth, and fifth item in the list. ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

print(list_fruits[2:5])

# 13.Use the correct syntax to print the number of items in the list. ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

print(len(list_fruits))

# 14.Use the correct syntax to sort this list in reverse order ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

list_fruits.sort(reverse = True)
print(list_fruits)

# 15.Use the DateTime module to get Current Date and Time, and save it to a variable. Then extract just the Full month name from that variable.
import datetime as dt
a = dt.datetime.now()
print("Current Date and Time ...", a)

print(a.strftime("%B"))

#15.
# Write a simple function that takes 2 parameters -- a first name and a day name.
# Set a default value for the day name of Sunday.
# Have the function print out a greeting -- using the parameters -- that says something like "Hi first-name! Happy day-name!". Remember to use the variables in the greeting to replace first-name and day-name.
# Invoke this function with 2 variables.
# Invoke this function with 1 variable only.

def greet(first_name, day_name):
    def greet(first_name = "Srujana", day_name = "Sunday"):
        print(f"Hi, {first_name}! Happy {day_name}!")

        greet("Srujana", "Sunday")
        greet("Srujana")

# 16.Write a block of code to handle one of the most common Python exception errors. Select one of the common errors from the curriculum section on Python Exception handling. Have your code example uses the try,except, else, and finally components.


try:
    print("Hello")
except:
    print("An Exception")
else:
    print("Nothing went wrong")
finally:
  print("The 'try except' is finished")
# Out:
# Renting a car is more affordable.
# Renting a car is more affordable.
# Renting a car is very expensive.
# 42
# e u i o o u o e e a o trousers cerise
# trousers gunmetal blue
# trousers Dark Sapphire
# trousers auburn
# trousers fuchsia
# trousers aqua
# trousers maple
# trousers burnt sienna
# blouse cerise
# blouse gunmetal blue
# blouse Dark Sapphire
# blouse auburn
# blouse fuchsia
# blouse aqua
# blouse maple
# blouse burnt sienna
# bandana cerise
# bandana gunmetal blue
# bandana Dark Sapphire
# bandana auburn
# bandana fuchsia
# bandana aqua
# bandana maple
# bandana burnt sienna
# cumber band cerise
# cumber band gunmetal blue
# cumber band Dark Sapphire
# cumber band auburn
# cumber band fuchsia
# cumber band aqua
# cumber band maple
# cumber band burnt sienna
# blazer cerise
# blazer gunmetal blue
# blazer Dark Sapphire
# blazer auburn
# blazer fuchsia
# blazer aqua
# blazer maple
# blazer burnt sienna
# vest cerise
# vest gunmetal blue
# vest Dark Sapphire
# vest auburn
# vest fuchsia
# vest aqua
# vest maple
# vest burnt sienna
# french beret cerise
# french beret gunmetal blue
# french beret Dark Sapphire
# french beret auburn
# french beret fuchsia
# french beret aqua
# french beret maple
# french beret burnt sienna
# scarf cerise
# scarf gunmetal blue
# scarf Dark Sapphire
# scarf auburn
# scarf fuchsia
# scarf aqua
# scarf maple
# scarf burnt sienna
# stole cerise
# stole gunmetal blue
# stole Dark Sapphire
# stole auburn
# stole fuchsia
# stole aqua
# stole maple
# stole burnt sienna
# The sum of all numbers from 1 to 100 is: 5050
# banana
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'lemon', 'banana', 'cherry', 'orange']
# ['apple', 'lemon', 'cherry', 'orange']
# orange melon
# ['cherry', 'orange', 'kiwi']
# 7
# ['orange', 'melon', 'mango', 'kiwi', 'cherry', 'banana', 'apple']
# Current Date and Time ... 2024-10-19 20:20:36.845674
# October
# Hello
# Nothing went wrong
# The 'try except' is finished
